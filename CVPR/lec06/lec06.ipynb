# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import importlib
import copy
import sys 
sys.path.append("..")

# reload module in case that module changes
from lib import utils
importlib.reload(utils)
from lib import image_process
importlib.reload(image_process)
# Out:
# <module 'lib.image_process' from '..\\lib\\image_process.py'>

# %%
img = cv2.imread('img/example_02.jpg', cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=(16,16))
utils.show_img(img)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
plt.figure(figsize=(16, 32))
plt.subplot(121)
img_2 = image_process.subsample(img, 2, 2)
utils.show_img(img_2)
plt.title('subsample factor=2*2 without filtered')
plt.subplot(122)
img_2_filtered = image_process.subsample_after_filtered(img, 2, 2)
utils.show_img(utils.normalize(img_2_filtered))
plt.title('subsample factor=2*2 after filtered')
# Out:
# Text(0.5, 1.0, 'subsample factor=2*2 after filtered')

# %%
plt.figure(figsize=(8, 16))
plt.subplot(121)
img_4 = image_process.subsample(img, 4, 4)
utils.show_img(img_4)
plt.title('subsample factor=4*4 without filtered')
plt.subplot(122)
img_4_filtered = image_process.subsample_after_filtered(img, 4, 4)
utils.show_img(utils.normalize(img_4_filtered))
plt.title('subsample factor=4*4 after filtered')
# Out:
# Text(0.5, 1.0, 'subsample factor=4*4 after filtered')

# %%
plt.figure(figsize=(4, 8))
plt.subplot(121)
img_8 = image_process.subsample(img, 8, 8)
utils.show_img(img_8)
plt.title('without filtered')
plt.subplot(122)
img_8_filtered = image_process.subsample_after_filtered(img, 8, 8)
utils.show_img(utils.normalize(img_8_filtered))
plt.title('after filtered')
# Out:
# Text(0.5, 1.0, 'after filtered')
